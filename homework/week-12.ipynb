# %% [markdown]
# <a href="https://colab.research.google.com/github/yuthimreddy/ds1002-hva4zb/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

import matplotlib.pyplot as plt

labels = 'US', 'UK', 'MX', 'CA', 'JP'
sizes = [56, 66, 24, 124, 47]

colors = ['#ff7e7e', '#D2FF99', '#7EC9FF', '#FEA8FF', '#FFEA7F']

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels,colors=colors, autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd03c6e14e0>,
#   <matplotlib.patches.Wedge at 0x7fd03c6e1420>,
#   <matplotlib.patches.Wedge at 0x7fd03c6e2140>,
#   <matplotlib.patches.Wedge at 0x7fd03c6e27d0>,
#   <matplotlib.patches.Wedge at 0x7fd03c6e2e60>],
#  [Text(0.9349011005821531, 0.5796205069959818, 'US'),
#   Text(-0.21125715497921718, 1.079523234798625, 'UK'),
#   Text(-0.9728300181275684, 0.5134216160524556, 'MX'),
#   Text(-0.6116935558191647, -0.9142379306117783, 'CA'),
#   Text(0.9828146941303805, -0.49403975245055637, 'JP')],
#  [Text(0.5099460548629926, 0.31615664017962636, '17.7%'),
#   Text(-0.11523117544320936, 0.5888308553447045, '20.8%'),
#   Text(-0.53063455534231, 0.2800481542104303, '7.6%'),
#   Text(-0.3336510304468171, -0.4986752348791517, '39.1%'),
#   Text(0.5360807422529348, -0.26947622860939435, '14.8%')])

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# Create a random number generator with a fixed seed for reproducibility
rng = np.random.default_rng(19680801)

plt.hist(n)
plt.title("Random Data Histogram")

plt.show()

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)
plt.scatter(x, y)

import seaborn as sns
sns.regplot(x=x,  y=y, ci=False, line_kws={'color':'red'})

plt.show()

# If you want them combined into a dataframe:
#df = pd.DataFrame({'x': x, 'y': y})
