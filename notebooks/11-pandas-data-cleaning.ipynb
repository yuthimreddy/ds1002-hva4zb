# %% [markdown]
# <a href="https://colab.research.google.com/github/yuthimreddy/ds1002-hva4zb/blob/main/notebooks/11-pandas-data-cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas DataFrames - Data Cleaning
#
# ```
#   University of Virginia
#   Programming for Data Science
#   Last Updated: September 22, 2023
# ```
#
# ### OBJECTIVES
# - Introduce pandas data cleaning tools

# %%
#import dependencies
import pandas as pd

# %%
dupes = pd.read_csv('./dupe-vals.csv')

# %% [markdown]
# **`.tail()`**
# * last records in dataframe

# %%
dupes.tail(40)
#len(dupes)
# Out:
#             pickup        dropoff  passengers  distance  fare   tip  tolls  \
# 81   3/16/19 18:57  3/16/19 19:00           2      0.40   4.0  0.00   0.00
# 82   3/14/19 11:55  3/14/19 12:08           6      1.84  10.0  2.66   0.00
# 83   3/16/19 21:03  3/16/19 21:21           1      2.50  12.5  1.50   0.00
# 84    3/9/19 19:54   3/9/19 20:07           2      1.50   9.5  0.00   0.00
# 85    3/3/19 16:44   3/3/19 16:48           1      1.02   5.0  2.08   0.00
# 86    3/4/19 20:20   3/4/19 20:24           1      0.60   5.0  0.00   0.00
# 87   3/28/19 22:57  3/28/19 23:16           1      4.10  16.0  0.00   0.00
# 88    3/16/19 5:08   3/16/19 5:08           1      0.07   2.5  0.00   0.00
# 89   3/27/19 22:22  3/27/19 22:41           1      5.99  20.0  5.95   0.00
# 90    3/7/19 10:39   3/7/19 11:05           5      2.55  16.5  0.00   0.00
# 91    3/11/19 8:46   3/11/19 8:47           1      0.30   3.0  0.95   0.00
# 92    3/28/19 7:05   3/28/19 7:41           0     10.60  33.5  0.00   5.76
# 93   3/12/19 12:02  3/12/19 12:17           3      0.66   9.5  1.20   0.00
# 94    3/6/19 20:00   3/6/19 20:11           3      2.60  11.0  4.40   0.00
# 95   3/28/19 21:30  3/28/19 21:42           1      1.60   9.0  2.55   0.00
# 96   3/13/19 16:11  3/13/19 16:28           1      3.21  13.5  0.00   0.00
# 97    3/4/19 22:34   3/4/19 22:41           1      1.30   7.5  0.50   0.00
# 98    3/8/19 19:10   3/8/19 19:18           2      0.90   7.0  0.00   0.00
# 99    3/2/19 10:47   3/2/19 10:56           3      0.95   7.5  2.16   0.00
# 100  3/17/19 22:47  3/17/19 22:55           1      1.30   7.5  2.25   0.00
# 101  3/15/19 23:46  3/15/19 23:59           1      1.47   9.5  0.00   0.00
# 102  3/16/19 18:57  3/16/19 19:00           2      0.40   4.0  0.00   0.00
# 103  3/14/19 11:55  3/14/19 12:08           6      1.84  10.0  2.66   0.00
# 104  3/16/19 21:03  3/16/19 21:21           1      2.50  12.5  1.50   0.00
# 105   3/9/19 19:54   3/9/19 20:07           2      1.50   9.5  0.00   0.00
# 106   3/3/19 16:44   3/3/19 16:48           1      1.02   5.0  2.08   0.00
# 107   3/4/19 20:20   3/4/19 20:24           1      0.60   5.0  0.00   0.00
# 108  3/28/19 22:57  3/28/19 23:16           1      4.10  16.0  0.00   0.00
# 109   3/16/19 5:08   3/16/19 5:08           1      0.07   2.5  0.00   0.00
# 110  3/27/19 22:22  3/27/19 22:41           1      5.99  20.0  5.95   0.00
# 111   3/7/19 10:39   3/7/19 11:05           5      2.55  16.5  0.00   0.00
# 112   3/11/19 8:46   3/11/19 8:47           1      0.30   3.0  0.95   0.00
# 113   3/28/19 7:05   3/28/19 7:41           0     10.60  33.5  0.00   5.76
# 114  3/12/19 12:02  3/12/19 12:17           3      0.66   9.5  1.20   0.00
# 115   3/6/19 20:00   3/6/19 20:11           3      2.60  11.0  4.40   0.00
# 116  3/28/19 21:30  3/28/19 21:42           1      1.60   9.0  2.55   0.00
# 117  3/13/19 16:11  3/13/19 16:28           1      3.21  13.5  0.00   0.00
# 118   3/4/19 22:34   3/4/19 22:41           1      1.30   7.5  0.50   0.00
# 119   3/8/19 19:10   3/8/19 19:18           2      0.90   7.0  0.00   0.00
# 120   3/2/19 10:47   3/2/19 10:56           3      0.95   7.5  2.16   0.00
#
#      total   color      payment                    pickup_zone  \
# 81    7.30  yellow         cash          Upper East Side North
# 82   15.96  yellow  credit card              East Harlem South
# 83   17.80  yellow  credit card  Meatpacking/West Village West
# 84   12.80  yellow         cash                       Gramercy
# 85   10.38  yellow  credit card                       Kips Bay
# 86    6.30  yellow         cash            Morningside Heights
# 87   19.80  yellow         cash                      Hudson Sq
# 88    3.80  yellow         cash                        Astoria
# 89   29.75  yellow  credit card        Greenwich Village South
# 90   19.80  yellow         cash                 Midtown Center
# 91    7.25  yellow  credit card          Upper East Side North
# 92   40.06  yellow  credit card                   East Tremont
# 93   14.00  yellow  credit card  Sutton Place/Turtle Bay North
# 94   19.20  yellow  credit card          Upper East Side South
# 95   15.35  yellow  credit card   Penn Station/Madison Sq West
# 96   17.80  yellow         cash       Financial District South
# 97   11.80  yellow  credit card                 Midtown Center
# 98   11.30  yellow         cash                  Midtown North
# 99   12.96  yellow  credit card                   West Village
# 100  13.55  yellow  credit card      West Chelsea/Hudson Yards
# 101  13.30  yellow         cash                   Midtown East
# 102   7.30  yellow         cash          Upper East Side North
# 103  15.96  yellow  credit card              East Harlem South
# 104  17.80  yellow  credit card  Meatpacking/West Village West
# 105  12.80  yellow         cash                       Gramercy
# 106  10.38  yellow  credit card                       Kips Bay
# 107   6.30  yellow         cash            Morningside Heights
# 108  19.80  yellow         cash                      Hudson Sq
# 109   3.80  yellow         cash                        Astoria
# 110  29.75  yellow  credit card        Greenwich Village South
# 111  19.80  yellow         cash                 Midtown Center
# 112   7.25  yellow  credit card          Upper East Side North
# 113  40.06  yellow  credit card                   East Tremont
# 114  14.00  yellow  credit card  Sutton Place/Turtle Bay North
# 115  19.20  yellow  credit card          Upper East Side South
# 116  15.35  yellow  credit card   Penn Station/Madison Sq West
# 117  17.80  yellow         cash       Financial District South
# 118  11.80  yellow  credit card                 Midtown Center
# 119  11.30  yellow         cash                  Midtown North
# 120  12.96  yellow  credit card                   West Village
#
#                        dropoff_zone pickup_borough dropoff_borough
# 81            Upper East Side North      Manhattan       Manhattan
# 82            Upper East Side South      Manhattan       Manhattan
# 83                        Chinatown      Manhattan       Manhattan
# 84     Penn Station/Madison Sq West      Manhattan       Manhattan
# 85   Stuy Town/Peter Cooper Village      Manhattan       Manhattan
# 86              Morningside Heights      Manhattan       Manhattan
# 87              Lincoln Square East      Manhattan       Manhattan
# 88                          Astoria         Queens          Queens
# 89                   Yorkville West      Manhattan       Manhattan
# 90              Little Italy/NoLiTa      Manhattan       Manhattan
# 91            Upper East Side North      Manhattan       Manhattan
# 92                     Midtown East          Bronx       Manhattan
# 93                   Midtown Center      Manhattan       Manhattan
# 94            Upper West Side North      Manhattan       Manhattan
# 95   Stuy Town/Peter Cooper Village      Manhattan       Manhattan
# 96      Downtown Brooklyn/MetroTech      Manhattan        Brooklyn
# 97            Upper East Side South      Manhattan       Manhattan
# 98        Times Sq/Theatre District      Manhattan       Manhattan
# 99                         Flatiron      Manhattan       Manhattan
# 100   Meatpacking/West Village West      Manhattan       Manhattan
# 101    Penn Station/Madison Sq West      Manhattan       Manhattan
# 102           Upper East Side North      Manhattan       Manhattan
# 103           Upper East Side South      Manhattan       Manhattan
# 104                       Chinatown      Manhattan       Manhattan
# 105    Penn Station/Madison Sq West      Manhattan       Manhattan
# 106  Stuy Town/Peter Cooper Village      Manhattan       Manhattan
# 107             Morningside Heights      Manhattan       Manhattan
# 108             Lincoln Square East      Manhattan       Manhattan
# 109                         Astoria         Queens          Queens
# 110                  Yorkville West      Manhattan       Manhattan
# 111             Little Italy/NoLiTa      Manhattan       Manhattan
# 112           Upper East Side North      Manhattan       Manhattan
# 113                    Midtown East          Bronx       Manhattan
# 114                  Midtown Center      Manhattan       Manhattan
# 115           Upper West Side North      Manhattan       Manhattan
# 116  Stuy Town/Peter Cooper Village      Manhattan       Manhattan
# 117     Downtown Brooklyn/MetroTech      Manhattan        Brooklyn
# 118           Upper East Side South      Manhattan       Manhattan
# 119       Times Sq/Theatre District      Manhattan       Manhattan
# 120                        Flatiron      Manhattan       Manhattan

# %% [markdown]
# # Working with Duplicate Data
#
# Pandas can identify duplicate rows and duplicate columns within a DataFrame

# %%
#are there any rows that are duplicated? field for field match?
dupes.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 116     True
# 117     True
# 118     True
# 119     True
# 120     True
# Length: 121, dtype: bool

# %%
# let's get a total of how many rows are duplicate, most of the time we nuke duplicate copies (get rid of them)
print(dupes.duplicated().sum())
# Out:
# 21

# %%
# remove the duplicate rows - but be sure to keep one copy! command takes no parameters
#overrides the original "dupes", changed the dataframe
dupes = dupes.drop_duplicates()

# %%
len(dupes)
# Out:
# 100

# %% [markdown]
# # Working with Missing Data
#
# Pandas primarily uses the data type `np.nan` from NumPy to represent missing data.

# %%
import numpy as np

# %%
df_miss = pd.DataFrame({
    'x':[2, np.nan, 1],
    'y':[np.nan, np.nan, 6],
    'z':[4, np.nan, np.nan]}
)

# %% [markdown]
# nan = null value

# %%
df_miss
# Out:
#      x    y    z
# 0  2.0  NaN  4.0
# 1  NaN  NaN  NaN
# 2  1.0  6.0  NaN

# %% [markdown]
# ## `.dropna()`
#
# This will drop all rows with missing data in any column; dropna says whenever you have a row with missing data, nuke it.
#
#
# [Details](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html)

# %%
df_drop_all = df_miss.dropna()
df_drop_all
# Out:
# Empty DataFrame
# Columns: [x, y, z]
# Index: []

# %% [markdown]
# The `subset` parameter takes a list of column names to specify which columns should have missing values.

# %%
df_drop_x = df_miss.dropna(subset=['x'])
df_drop_x
# Out:
#      x    y    z
# 0  2.0  NaN  4.0
# 2  1.0  6.0  NaN

# %% [markdown]
# ## `.fillna()`
#
# This will replace missing values with whatever you set it to, e.g. $0$s.
#
# [Details](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html)
#
# We can pass the results of an operation -- for example to peform simple imputation, we can replace missing values in each column with the median value of the respective column: we can impute the mean as a value

# %%
df_filled = df_miss.fillna(df_miss.median())

# %% [markdown]
# Using the df.miss dataframe, then followed with the fillna command with the parameter of filling the null values with the medians. The new assigned values are now **imputed values**.

# %%
df_filled
# Out:
#      x    y    z
# 0  2.0  6.0  4.0
# 1  1.5  6.0  4.0
# 2  1.0  6.0  4.0

# %% [markdown]
# # Try It Yourself
#
# Fetch the `very-messy-data.csv` file [here](https://github.com/nmagee/ds1002/blob/main/data/very-messy-data.csv) and drag it into the files of this notebook.
#
# Using the methods you learned above, practice your skills by doing the following:
#
# 1. Remove duplicate lines
# 2. Where you are missing species data, remove those lines.
# 3. Where you are missing other data, impute data based on the mean of the rest of that column. Repeat for any columns with missing data.

# %%
messy = pd.read_csv("very-messy-data.csv")
