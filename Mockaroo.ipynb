# %% [markdown]
# <a href="https://colab.research.google.com/github/yuthimreddy/ds1002-hva4zb/blob/main/Mockaroo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#import the mockaroo file - mock_data name of pandas dataframe, we are creatinig an object which is the pandas dataframe
mock_data = pd.read_csv("MOCK_DATA.csv")

# %%
mock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   age         1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB

# %% [markdown]
# an object in pandas = strings in python

# %%
mock_data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#get the head rows - whatever number you think
mock_data.head(3)
# Out:
#    id first_name last_name                   email  gender  age
# 0   1   Crichton   Kissick      ckissick0@bing.com    Male    1
# 1   2    Scottie    Soutar  ssoutar1@google.com.hk    Male   25
# 2   3      Jaime    Lawlie       jlawlie2@yale.edu  Female   29

# %%
mock_data.tail()
# Out:
#        id first_name  last_name                         email       gender  \
# 995   996   Ingeborg       Aird            iairdrn@oakley.com  Genderqueer
# 996   997      Marcy  Saltsberg  msaltsbergro@theatlantic.com       Female
# 997   998     Zsazsa     Gumery             zgumeryrp@last.fm       Female
# 998   999      Tildi       Fysh             tfyshrq@slate.com       Female
# 999  1000     Lianne    Ghiotto     lghiottorr@shutterfly.com       Female
#
#      age
# 995   16
# 996   80
# 997   66
# 998   16
# 999   83

# %%
#mockdata is the data loc is the location and the number is the index, grab a specific from from a ds
mock_data.loc[9]
# Out:
# id                             10
# first_name                Carroll
# last_name               Pepperill
# email         cpepperill9@nba.com
# gender                       Male
# age                            46
# Name: 9, dtype: object

# %%
#can put parameters or modifiers in the parentheses, can get more specific
mock_data.describe()
# Out:
#                 id          age
# count  1000.000000  1000.000000
# mean    500.500000    45.663000
# std     288.819436    25.900662
# min       1.000000     1.000000
# 25%     250.750000    24.000000
# 50%     500.500000    47.000000
# 75%     750.250000    68.000000
# max    1000.000000    90.000000

# %%
#get the columns from the df
mock_data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'age'], dtype='object')

# %%
#2 types= strings and objects
mock_data.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# age            int64
# dtype: object

# %%
#we can change the df now (just in memory)
mock_data = mock_data.rename(columns={"first_name":"fname","last_name":"lname"})

# %%
mock_data.head()
# Out:
#    id     fname    lname                   email  gender  age
# 0   1  Crichton  Kissick      ckissick0@bing.com    Male    1
# 1   2   Scottie   Soutar  ssoutar1@google.com.hk    Male   25
# 2   3     Jaime   Lawlie       jlawlie2@yale.edu  Female   29
# 3   4    Dniren   Antham       dantham3@time.com  Female   72
# 4   5  Benedict   Seabon    bseabon4@alibaba.com    Male   55

# %%
mock_data['fname']
# Out:
# 0      Crichton
# 1       Scottie
# 2         Jaime
# 3        Dniren
# 4      Benedict
#          ...
# 995    Ingeborg
# 996       Marcy
# 997      Zsazsa
# 998       Tildi
# 999      Lianne
# Name: fname, Length: 1000, dtype: object

# %%
mock_data.fname
# Out:
# 0      Crichton
# 1       Scottie
# 2         Jaime
# 3        Dniren
# 4      Benedict
#          ...
# 995    Ingeborg
# 996       Marcy
# 997      Zsazsa
# 998       Tildi
# 999      Lianne
# Name: fname, Length: 1000, dtype: object

# %%
mock_data[['fname','lname']]
# Out:
#         fname      lname
# 0    Crichton    Kissick
# 1     Scottie     Soutar
# 2       Jaime     Lawlie
# 3      Dniren     Antham
# 4    Benedict     Seabon
# ..        ...        ...
# 995  Ingeborg       Aird
# 996     Marcy  Saltsberg
# 997    Zsazsa     Gumery
# 998     Tildi       Fysh
# 999    Lianne    Ghiotto
#
# [1000 rows x 2 columns]

# %%
pd.value_counts(mock_data['gender']).plot.bar()
# Out:
# <Axes: >

# %%
mock_data.groupby(['gender'])['age'].mean()
# Out:
# gender
# Agender        45.083333
# Bigender       50.066667
# Female         46.206074
# Genderfluid    45.285714
# Genderqueer    40.300000
# Male           45.106095
# Non-binary     51.230769
# Polygender     44.333333
# Name: age, dtype: float64
